# %% [markdown]
# # Data Exploration Notebook
#
# This notebook explores the dataset and performs initial analysis.

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Key Insights
#
# 1. The dataset has no missing values
# 2. Classes are balanced (50 samples each)
# 3. Some features show strong correlations
# 4. Features show good separation between classes
# 5. No significant outliers detected
